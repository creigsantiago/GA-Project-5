# %%
import pandas as pd

# %%
df = pd.read_stata('../Data/Havard Dataset/cumulative_2006-2020.dta')

# %%
df.shape
# Out:
# (531755, 93)

# %%
df.head()
# Out:
#    year case_id    weight  weight_cumulative           state  st cong cong_up  \
# 0  2006  439219  1.851676           1.667581  North Carolina  NC  109     110
# 1  2006  439224  0.968308           0.872039            Ohio  OH  109     110
# 2  2006  439228  1.593441           1.435020      New Jersey  NJ  109     110
# 3  2006  439237  1.398529           1.259486        Illinois  IL  109     110
# 4  2006  439238  0.902890           0.813124        New York  NY  109     110
#
#        state_post st_post  ...          voted_rep_chosen  \
# 0  North Carolina      NC  ...    Richard C. Carsner (D)
# 1            Ohio      OH  ...  Stephanie Studebaker (D)
# 2      New Jersey      NJ  ...     Robert E. Andrews (D)
# 3        Illinois      IL  ...  Janice D. Schakowsky (D)
# 4        New York      NY  ...    Maurice D. Hinchey (D)
#
#              voted_sen_chosen     voted_gov_chosen               rep_current  \
# ...

# %%
df = df[df['st_post']== 'VA']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9719 entries, 86 to 531632
# Data columns (total 93 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               9719 non-null   int32
#  1   case_id            9719 non-null   object
#  2   weight             9719 non-null   float64
#  3   weight_cumulative  9719 non-null   float64
#  4   state              9719 non-null   category
#  5   st                 9719 non-null   category
#  6   cong               9719 non-null   category
#  7   cong_up            9719 non-null   category
#  8   state_post         9719 non-null   category
#  9   st_post            9719 non-null   category
#  10  dist               9719 non-null   int32
#  11  dist_up            9719 non-null   int32
#  12  cd                 9719 non-null   object
#  13  cd_up              9719 non-null   object
#  14  dist_post          9719 non-null   float64
# ...

# %%
df[['dist']].value_counts()
# Out:
# dist
# 7       1058
# 8        952
# 10       938
# 6        937
# 3        899
# 1        898
# 11       872
# 4        799
# 9        794
# 5        784
# 2        779
# 12         2
# 18         2
# 24         2
# 20         1
# 25         1
# 46         1
# dtype: int64
